# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
from scripts1 import project_functions
data = project_functions.load_and_process("https://raw.githubusercontent.com/data301-2020-winter2/course-project-group_1018/main/data/raw/AirQualityUCI.csv")
data
# Out:
#             Date Hour of Day  CO(GT)  Tin Oxide  Benzene(GT)  \
# 0     10/03/2004    18.00.00     2.6     1360.0         11.9
# 1     10/03/2004    19.00.00     2.0     1292.0          9.4
# 2     10/03/2004    20.00.00     2.2     1402.0          9.0
# 3     10/03/2004    21.00.00     2.2     1376.0          9.2
# 4     10/03/2004    22.00.00     1.6     1272.0          6.5
# ...          ...         ...     ...        ...          ...
# 9352  04/04/2005    10.00.00     3.1     1314.0         13.5
# 9353  04/04/2005    11.00.00     2.4     1163.0         11.4
# 9354  04/04/2005    12.00.00     2.4     1142.0         12.4
# 9355  04/04/2005    13.00.00     2.1     1003.0          9.5
# 9356  04/04/2005    14.00.00     2.2     1071.0         11.9
#
#       Tungsten Oxide(GT)  Tungsten Oxide  Temperature  Relative Humidity  \
# 0                  113.0          1692.0         13.6               48.9
# 1                   92.0          1559.0         13.3               47.7
# ...

# %%
data.describe()
# Out:
#             CO(GT)    Tin Oxide  Benzene(GT)  Tungsten Oxide(GT)  \
# count  9357.000000  9357.000000  9357.000000         9357.000000
# mean    -34.207524  1048.990061     1.865683           58.148873
# std      77.657170   329.832710    41.380206          126.940455
# min    -200.000000  -200.000000  -200.000000         -200.000000
# 25%       0.600000   921.000000     4.000000           53.000000
# 50%       1.500000  1053.000000     7.900000           96.000000
# 75%       2.600000  1221.000000    13.600000          133.000000
# max      11.900000  2040.000000    63.700000          340.000000
#
#        Tungsten Oxide  Temperature  Relative Humidity  Absolute Humidity
# count     9357.000000  9357.000000        9357.000000        9357.000000
# mean      1391.479641     9.778305          39.485380          -6.837604
# std        467.210125    43.203623          51.216145          38.976670
# min       -200.000000  -200.000000        -200.000000        -200.000000
# ...

# %%
data.drop(columns = ['Tin Oxide' , 'Tungsten Oxide', 'Absolute Humidity'])
# Out:
#             Date Hour of Day  CO(GT)  Benzene(GT)  Tungsten Oxide(GT)  \
# 0     10/03/2004    18.00.00     2.6         11.9               113.0
# 1     10/03/2004    19.00.00     2.0          9.4                92.0
# 2     10/03/2004    20.00.00     2.2          9.0               114.0
# 3     10/03/2004    21.00.00     2.2          9.2               122.0
# 4     10/03/2004    22.00.00     1.6          6.5               116.0
# ...          ...         ...     ...          ...                 ...
# 9352  04/04/2005    10.00.00     3.1         13.5               190.0
# 9353  04/04/2005    11.00.00     2.4         11.4               179.0
# 9354  04/04/2005    12.00.00     2.4         12.4               175.0
# 9355  04/04/2005    13.00.00     2.1          9.5               156.0
# 9356  04/04/2005    14.00.00     2.2         11.9               168.0
#
#       Temperature  Relative Humidity
# 0            13.6               48.9
# 1            13.3               47.7
# ...

# %%
sns.heatmap(data.corr(),annot=True)
plt.title('Heatmap of co-relation between variables',fontsize=18)
plt.show()
#This heatmap shows the co-relation between each of the variables
#It is clear that there is a high correlation between the Temperature and presence of gases such as Tin Oxide and Tungsten Oxide
#This could be attributed to the the harmful nature of these gases and hence, the greenhouse effect

# %%
import pandas_profiling as pdp
from pandas_profiling import ProfileReport
#your solution here
profileReport = pdp.ProfileReport(data)
profileReport
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-8bc70558fe51> in <module>
# ----> 1 import pandas_profiling as pdp
#       2 from pandas_profiling import ProfileReport
#       3 #your solution here
#       4 profileReport = pdp.ProfileReport(data)
#       5 profileReport
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
#using pandas profiling, it can be seen on Pearson's r that the gases CO and Tungsten Oxide(NO2) have high concentrations (measured in mg/cubic meter)
#This could be related to the output of pollutants from cars and how why they are present at the same time in the atmosphere and recorded as such
#As this study progressses, we will be looking at how these values compare hourly and monthly, to see how rush hour and seasonal use of vehicles could affect air quality

#Furthermore, looking at the interactions between Tungsten Oxide and Tin Oxide, it can be seen that these gases are present together at the same time
#this helps confirm the findings in the heatmap displayed earlier on
