# %%
import pandas as pd
import matplotlib.pyplot as plt
from scripts1 import project_functions
data = project_functions.load_and_process("../data/raw/AirQualityUCI.csv")
data
# Out:
#             Date Hour of Day  CO(GT)  Tin Oxide  Benzene(GT)  \
# 0     10/03/2004    18.00.00     2.6     1360.0         11.9
# 1     10/03/2004    19.00.00     2.0     1292.0          9.4
# 2     10/03/2004    20.00.00     2.2     1402.0          9.0
# 3     10/03/2004    21.00.00     2.2     1376.0          9.2
# 4     10/03/2004    22.00.00     1.6     1272.0          6.5
# ...          ...         ...     ...        ...          ...
# 9352  04/04/2005    10.00.00     3.1     1314.0         13.5
# 9353  04/04/2005    11.00.00     2.4     1163.0         11.4
# 9354  04/04/2005    12.00.00     2.4     1142.0         12.4
# 9355  04/04/2005    13.00.00     2.1     1003.0          9.5
# 9356  04/04/2005    14.00.00     2.2     1071.0         11.9
#
#       Tungsten Oxide(GT)  Tungsten Oxide  Temperature  Relative Humidity  \
# 0                  113.0          1692.0         13.6               48.9
# 1                   92.0          1559.0         13.3               47.7
# ...

# %%
data.describe()
#This describes the characteristics of the clean data, however for some reason all the min values return a "-200" value.
# Out:
#             CO(GT)    Tin Oxide  Benzene(GT)  Tungsten Oxide(GT)  \
# count  9357.000000  9357.000000  9357.000000         9357.000000
# mean    -34.207524  1048.990061     1.865683           58.148873
# std      77.657170   329.832710    41.380206          126.940455
# min    -200.000000  -200.000000  -200.000000         -200.000000
# 25%       0.600000   921.000000     4.000000           53.000000
# 50%       1.500000  1053.000000     7.900000           96.000000
# 75%       2.600000  1221.000000    13.600000          133.000000
# max      11.900000  2040.000000    63.700000          340.000000
#
#        Tungsten Oxide  Temperature  Relative Humidity  Absolute Humidity
# count     9357.000000  9357.000000        9357.000000        9357.000000
# mean      1391.479641     9.778305          39.485380          -6.837604
# std        467.210125    43.203623          51.216145          38.976670
# min       -200.000000  -200.000000        -200.000000        -200.000000
# ...

# %%
import seaborn as sns

corr = data.corr()
sns.heatmap(data.corr(), annot = True, vmin=-1, vmax=1, center= 0, cmap= 'PiYG')
plt.title('Correlation Matrix between Columns',fontsize=12)
plt.show()

#Correlation Matrix between all the columns
#1. there is a good amount of correlation >.7 in Tin Oxide Column between other columns
#2. Relative Humidity also has a lot of high correlations between columns, along with Temperature and Absolute Humidity

# %%
sns.pairplot(data)

#This set of pairplots and the previous correlation matrix are the same essentially
#As correlation increases, the concentration of the plotted points on the scatterplot increase and are more densely "packed"
#And vice versa, this relationship holds true as correlation decreases as shown in the the "CO(GT)" and "Absolute Humidity" pairplot
#We see that the plots are extremely far apart although theyre still densely "packed" we can see the correlation is negative
#Due to the far distance between the 4 clusters of the plot.
